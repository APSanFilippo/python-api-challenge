# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
readcsv_df = pd.read_csv("cities.csv")
city_df = readcsv_df.drop(columns=["Unnamed: 0"])
city_df.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      Rikitea           4      PF  1584487686        78 -23.12 -134.97
# 1       Palmer          75      US  1584487649        75  42.16  -72.33
# 2      Samarai          38      PG  1584487692        74 -10.62  150.67
# 3        Conde          30      BR  1584487693        83  -7.26  -34.91
# 4  Tuktoyaktuk          75      CA  1584487693        84  69.45 -133.04
#
#    Max Temp  Wind Speed
# 0    80.978        5.32
# 1    48.470        2.10
# 2    82.652        2.49
# 3    80.870        3.10
# 4     1.670        1.50

# %%
gmaps.configure(api_key=g_key)
locations = city_df[["Lat", "Lng"]]
humidity = city_df["Humidity"].astype(float)

# %%
fig = gmaps.figure(center = [0,0] ,zoom_level = 2)

heatmap_layer = gmaps.heatmap_layer(locations, weights=humidity,
                                   dissipating=False, max_intensity=5,
                                   point_radius=1)

fig.add_layer(heatmap_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
temp_df_high = city_df.loc[city_df['Max Temp'] >=70]    
temp_low_df = temp_df_high.loc[temp_df_high['Max Temp']<=80]
wind_df=temp_low_df.loc[temp_low_df['Wind Speed']<=10]
ideal_weather_df=wind_df.loc[wind_df['Cloudiness']==0]
ideal_weather_df.head()
# Out:
#                City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 8         Koungheul           0      SN  1584487523        33  13.98  -14.80
# 65           Dwārka           0      IN  1584487619        65  22.24   68.97
# 89            Airai           0      TL  1584487591        67  -8.93  125.41
# 115            Buin           0      CL  1584487736        40 -33.73  -70.75
# 148  Port Elizabeth           0      ZA  1584487747        64 -33.92   25.57
#
#      Max Temp  Wind Speed
# 8      76.046        5.35
# 65     77.990        4.16
# 89     73.166        2.02
# 115    75.470        3.10
# 148    70.070        3.60

# %%
hotel_df = ideal_weather_df.reset_index(drop=True)
hotel_df["Hotel Name"] = ""

# params dictionary to update each iteration
params = {
    "radius": 50000,
    "types": "hotel",
    "keyword": "hotels",
    "key": g_key
}

# Use the lat/lng we recovered to identify hotels
for index, row in hotel_df.iterrows():
    
    # get lat, lng 
    lat = row["Lat"]
    lng = row["Lng"]
    
    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"
    
    # Use the search term: "Hotels" and our lat/lng
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    # make request and print url
    hotel_name = requests.get(base_url, params=params)
    
    # convert to json
    hotel_name = hotel_name.json()
    print(json.dumps(hotel_name, indent=4, sort_keys=True))
    
    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotel_name["results"][0]["name"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
hotel_df
# Out:
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 14.36018,
#                     "lng": -14.46768
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 14.36152982989272,
#                         "lng": -14.46633017010728
#                     },
#                     "southwest": {
#                         "lat": 14.35883017010728,
#                         "lng": -14.46902982989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "87bef31de5aea17fac7cb1203438d82bc613013f",
#             "name": "Hotel Cabourg",
#             "place_id": "ChIJC06iXteP7g4R2YH0Jk5c3O8",
#             "plus_code": {
#                 "compound_code": "9G6J+3W Diouguel, Senegal",
#                 "global_code": "7C679G6J+3W"
#             },
#             "rating": 0,
#             "reference": "ChIJC06iXteP7g4R2YH0Jk5c3O8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "bp 8921 DAKAR - Yoff, Dakar"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 14.36018,
#                     "lng": -14.46768
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 14.36152982989272,
#                         "lng": -14.46633017010728
#                     },
#                     "southwest": {
#                         "lat": 14.35883017010728,
#                         "lng": -14.46902982989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "9346f612d2965ef10a0461ab3b426574c29fac91",
#             "name": "ARCHOTEL",
#             "place_id": "ChIJC06iXteP7g4R6GmwZTOproE",
#             "plus_code": {
#                 "compound_code": "9G6J+3W Diouguel, Senegal",
#                 "global_code": "7C679G6J+3W"
#             },
#             "rating": 5,
#             "reference": "ChIJC06iXteP7g4R6GmwZTOproE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Route de Ngor bp 29452 dakar, DAKAR"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 13.5395961,
#                     "lng": -14.757684
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 13.54080097989272,
#                         "lng": -14.75641632010728
#                     },
#                     "southwest": {
#                         "lat": 13.53810132010728,
#                         "lng": -14.75911597989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "6f84ecf379cb3c582eaf18e226c4b7721195e8f3",
#             "name": "Baobolong Camp and Guest House",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 640,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115482493455961589641\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAANOx_95FW8eIpjboFfWd1RcuJMx4CJuIaHSwEzQSlPONPpfjoJsVBchcQQxp5qG0QeRvjz6BiKqqheGpoaof523cTUsS4Y__jEhva7xCQiMgGmrltMjlS9A74c1Je797zEhAr3SWQrwDlyIn7WSbAMA6iGhRIBFbCUPvjtfnl5pZddAgiZFZ1vQ",
#                     "width": 1095
#                 }
#             ],
#             "place_id": "ChIJ2UDepL857w4RDQ9k9MwkMSs",
#             "plus_code": {
#                 "compound_code": "G6QR+RW Janjanbureh, Gambia",
#                 "global_code": "7C57G6QR+RW"
#             },
#             "rating": 3.3,
#             "reference": "ChIJ2UDepL857w4RDQ9k9MwkMSs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 7,
#             "vicinity": "Boraba street central river region, Janjanbureh"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 13.5336211,
#                     "lng": -14.7695962
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 13.53455387989272,
#                         "lng": -14.7673174
#                     },
#                     "southwest": {
#                         "lat": 13.53185422010728,
#                         "lng": -14.7703558
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "272400219fc3c1fab02dd4caa12dad95e9232815",
#             "name": "Musa's Garden Lodge",
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104889223573021634568\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAFXkMOWp8xMQRMWgjvFTlqeGtmptbhgTisSfmnpdahN3dImZe4BHOrUi6WrPRqnaPjGIrPCQyxA-ApmRpQ7_qUMlL0yZO-W5oFNhv8FFsDwg-EVpBayE5eCBWt57BeH0QEhAY8aj1Eu1Z5uYtYRflBAzaGhSALwpJ2ikd6-n884sO58ffk2V0Xg",
#                     "width": 2268
#                 }
#             ],
#             "place_id": "ChIJtxc3cf857w4RdzmLvJtpzy4",
#             "plus_code": {
#                 "compound_code": "G6MJ+C5 Janjanbureh, Gambia",
#                 "global_code": "7C57G6MJ+C5"
#             },
#             "rating": 0,
#             "reference": "ChIJtxc3cf857w4RdzmLvJtpzy4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "Janjanbureh"
#         }
#     ],
#     "status": "OK"
# }
# {
#     "html_attributions": [],
#     "next_page_token": "CrQCIgEAADQl5ByxEWdoHMRnX1dsMjmN5NUmFqJ3vt85_jfgPdhZOnqxZgw9BDCKxUbu1MTAza9swb-bJlKWWIgZZEtc3wrGbpbzh2nbOCelsdkRBz1wELLgVikKLzDYj91LxaifhYL4q2zlycGvt0COOX3WIeKonhnvk-xVVh9TEamBP-1oaNtdSA00XHhIyM-AB4X7Sj09aLug6zxxEqYRUp20SLmM2YxSruhYqe2kFlUWeQTxrUsywJ_h2Yx1jPB_R0_6WddqRgpdrD9y_nB9OUhMwSJt4HOfwPluEf9D8u6cgQD9Oek4QrqiH8s81lQy0nraxcJc_Iy-HQDEg5vn1CpPJr6j-SIbxrvQEC7LZLdmfsd7stj91uVdX52-RIrXF1o92aCA9po3MAOF7HRlQWcVaTgSEJK5O_7Vt7hAmguvHAhcWWAaFHVVjZW7tlHwZOwc2FO_4JAtzUPJ",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.243512,
#                     "lng": 68.96649479999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.24504012989272,
#                         "lng": 68.96790662989272
#                     },
#                     "southwest": {
#                         "lat": 22.24234047010727,
#                         "lng": 68.96520697010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "e9c4f7430e42ae17c2eb31be1fd0d7c6f07beae5",
#             "name": "VITS Devbhumi, Dwarka",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100662909796445973700\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAyFRoKun-pv7CTBIBXgydLG-gevXm7itpLGZfHSgrCMpJVNhcAHiWPz322cysro8E4GBSUd4YnDL1j4dd2fPgefHquSNMKKRPKWlcn7vTzTlrrB7hHvTxuhmbSPvI7KNBEhBq6vDH2Es2sxzVjXVNz1r_GhSgz4HyRUEFZD16HtTcvoxxDJCagw",
#                     "width": 4500
#                 }
#             ],
#             "place_id": "ChIJkziBByacVjkRzI7j5oITzts",
#             "plus_code": {
#                 "compound_code": "6XV8+CH Dwarka, Gujarat, India",
#                 "global_code": "7JJC6XV8+CH"
#             },
#             "rating": 4.2,
#             "reference": "ChIJkziBByacVjkRzI7j5oITzts",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1392,
#             "vicinity": "Okha State Highway, near Ravla Lake, opposite Post Office Road, Dwarka"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.2390117,
#                     "lng": 68.97084749999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.24012437989272,
#                         "lng": 68.97213262989271
#                     },
#                     "southwest": {
#                         "lat": 22.23742472010728,
#                         "lng": 68.96943297010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "505359a7b443d0c95f20b148de323ed585cda2b2",
#             "name": "The Grand Dwarika",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3648,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104059505630208664506\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA1gvG5dWLMnv2XRocztiZa2dMV6vBdMUfOtjZPjB-qyAV6kbXutYPayJs556I_J524KOfortYSnGJdFO5Wkf8U-J0Wdiw0-pKNynxYEEEtXxxB6AammBFIAOGrh7-K4UAEhDKblH5QFcN8u5loEhQ8osVGhTXcpvK3j8jVKHdNEy-CM2EmDClAA",
#                     "width": 4630
#                 }
#             ],
#             "place_id": "ChIJTwPctiScVjkRnm85jmv-o3A",
#             "plus_code": {
#                 "compound_code": "6XQC+J8 Dwarka, Gujarat, India",
#                 "global_code": "7JJC6XQC+J8"
#             },
#             "rating": 4.1,
#             "reference": "ChIJTwPctiScVjkRnm85jmv-o3A",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1179,
#             "vicinity": "Bhathan chok, Dwarkadhish Temple Rd, Dwarka"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.2029049,
#                     "lng": 69.0141355
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.20441092989272,
#                         "lng": 69.01585387989273
#                     },
#                     "southwest": {
#                         "lat": 22.20171127010728,
#                         "lng": 69.01315422010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "eac00c4f1d9394b97e633b1b7cdb1d0ff3547868",
#             "name": "The Fern Sattva Hotel & Resort Dwarka",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1250,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108973869287621208211\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAi_TF7_j3lGZMSzunHD5CJsPxqlvFpEBQgoWIoY77iK3SXcLLj1Ux_DXGpUlyK_wESLSxOPb_rBLumbsdx5T0kS5-mpI7Vj97GT0xX_9yor_mDl226yg0IE8TTwIQTf8-EhBSi-H9T5Cqysv1yhM0pS6YGhRUtaldgEK7XD5a2YBOYibEkiIqnw",
#                     "width": 2000
#                 }
#             ],
#             "place_id": "ChIJu40bgQebVjkRZPd1uwDp77c",
#             "plus_code": {
#                 "compound_code": "6237+5M Dwarka, Gujarat, India",
#                 "global_code": "7JJF6237+5M"
#             },
#             "rating": 4.4,
#             "reference": "ChIJu40bgQebVjkRZPd1uwDp77c",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 631,
#             "vicinity": "National Highway 51,At- Baradia, Dwarka"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.2081045,
#                     "lng": 69.0135312
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.20929267989272,
#                         "lng": 69.01447312989272
#                     },
#                     "southwest": {
#                         "lat": 22.20659302010728,
#                         "lng": 69.01177347010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "7c2760e95d606e5d0e67a0548d137a77257bbf89",
#             "name": "Club Mahindra Dwarka",
#             "photos": [
#                 {
#                     "height": 1456,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103802477106025782879\">Pradeep</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAydDNdb2Rnb7y_8nX1EIpo53Bh6pWqvij45qvDGF6_9n-RTQZQoSQIkDDB0UHJyxX5KDYSq-wYDXDwVLKAhFXhpGJWiWtN8Dr8akg8P8KiitbrH_jkgEpPlm9CQFQSg_AEhA4-97G1uYDl5lZ79LyoNrBGhRT2OdvxCOgxHsU4atqwnqkOfmpYQ",
#                     "width": 2592
#                 }
#             ],
#             "place_id": "ChIJO9f_MHibVjkRW0dWCErESQs",
#             "plus_code": {
#                 "compound_code": "6257+6C Baradia, Gujarat, India",
#                 "global_code": "7JJF6257+6C"
#             },
#             "rating": 4.3,
#             "reference": "ChIJO9f_MHibVjkRW0dWCErESQs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 494,
#             "vicinity": "National Highway No 8, Dwarka"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.2358148,
#                     "lng": 68.9655835
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.23728342989272,
#                         "lng": 68.96687592989271
#                     },
#                     "southwest": {
#                         "lat": 22.23458377010728,
#                         "lng": 68.96417627010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "33a0819fcaffeafa0ddc120cbaf6cf2e439baf6d",
#             "name": "Devbhoomi Residency, Dwarika (Gujarat) India",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 393,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116895677485304418991\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAhvMruWCy-dS0824VbmT7RQrzGR-6hWCCu4F_QPsE_Z51aCc-f1FZ_Ti7dCGVXCy8yT48jLrr3VtZpy2UtVR3caPRyN_XjOlYmv9OIYAZa9gvGbNJ1uhn-AqVtl6AjlDtEhCOK74NsV-KrUuP-pMzYDS2GhS6PGSTvzbZfqb11mLxOwv5U9pz6w",
#                     "width": 699
#                 }
#             ],
#             "place_id": "ChIJRdZseDCcVjkRtV-GW3SHSrs",
#             "plus_code": {
#                 "compound_code": "6XP8+86 Dwarka, Gujarat, India",
#                 "global_code": "7JJC6XP8+86"
#             },
#             "rating": 4.4,
#             "reference": "ChIJRdZseDCcVjkRtV-GW3SHSrs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 109,
#             "vicinity": "Dwarka"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.2097718,
#                     "lng": 69.01098990000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.21126177989272,
#                         "lng": 69.01264527989272
#                     },
#                     "southwest": {
#                         "lat": 22.20856212010728,
#                         "lng": 69.00994562010729
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "8a203fad5179d12c873e86513c98c33dae43990b",
#             "name": "Ginger Dwarka",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1609,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114241496621361187122\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAf7etm9Nw9jyKn-XMrG3FQSi5dRwBJHI42GAqASbyPAqZ-Rfat-vkLJyVuC83Jx3Sh7GKcFNIWBL9lUOb_VYQv0AFpJjh6m1ODfNQ57ECyzdGbJkdNSq-4c7yjh_xq8vaEhCRHVpF17zgyIOuqvsPyGzgGhSEn9_Uj9c-lEGv_S20wWE2XD1VAQ",
#                     "width": 3529
#                 }
#             ],
#             "place_id": "ChIJqRHfBLKbVjkRTACIhZHYuzs",
#             "plus_code": {
#                 "compound_code": "6256+W9 Dwarka, Gujarat, India",
#                 "global_code": "7JJF6256+W9"
#             },
#             "rating": 3.6,
#             "reference": "ChIJqRHfBLKbVjkRTACIhZHYuzs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 162,
#             "vicinity": "PORBANDAR DWARKA HIGHWAY NH 51, Taluk, Dwarka"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.2400689,
#                     "lng": 68.964575
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.24138377989272,
#                         "lng": 68.96585232989273
#                     },
#                     "southwest": {
#                         "lat": 22.23868412010727,
#                         "lng": 68.96315267010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "337b2806a3958a270ada828a974149e5ecc6e3d8",
#             "name": "Hotel Pari",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1280,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109582559628135025163\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAq0IiqWXuK6esKpzIaOU_oxzIO9ThVYSoEtpiyxRDyjeBHnCVWg1IZ-gooC7-a7Pz6hR_16kVN34hsRKfp6v_5st9E00PaEASh13sSHT4spG54JEBZ3jBbFiJpp26ZrgDEhDm15GfqfCs5e7zprEHMTdOGhSRKBhirHEllM95U6XC-UYICwtxjw",
#                     "width": 960
#                 }
#             ],
#             "place_id": "ChIJXS4Lz_WdVjkRmydjHrZFlUE",
#             "plus_code": {
#                 "compound_code": "6XR7+2R Dwarka, Gujarat, India",
#                 "global_code": "7JJC6XR7+2R"
#             },
#             "rating": 4.8,
#             "reference": "ChIJXS4Lz_WdVjkRmydjHrZFlUE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 45,
#             "vicinity": "Home guard chowk, near Haveli, Dwarka"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.1899575,
#                     "lng": 69.0234722
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.19120092989272,
#                         "lng": 69.02470102989273
#                     },
#                     "southwest": {
#                         "lat": 22.18850127010727,
#                         "lng": 69.02200137010729
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "26f0697070871e6d813ac7751e862dc048cedfc5",
#             "name": "Mango Hotels SELECT Dwarka",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3313,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109120337241102151030\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA0oTeQhxccA7ZTIzBVn5tbTGEtw3DJ3Qnshwpg4k2dVG7OrCJ9hyIvSVtVl9erNGTOkzDi8xYerRsfKUGx_WfAuxAWsd7RyQLQ28Lu_Z_wClMfmZJD6pizJQZZZCTi6F5EhAlRM0vXDVz3RFvU0ASD74hGhTMhXJr1HnsGZN5kXIR_DdNLJqYow",
#                     "width": 5361
#                 }
#             ],
#             "place_id": "ChIJQZxISYFRXzkRVmnBr0PhkxU",
#             "plus_code": {
#                 "compound_code": "52QF+X9 Baradia, Gujarat, India",
#                 "global_code": "7JJF52QF+X9"
#             },
#             "rating": 4.2,
#             "reference": "ChIJQZxISYFRXzkRVmnBr0PhkxU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 96,
#             "vicinity": "S.NO 389/P1, NH 51 Village Vachhu, Dwarka"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.24097,
#                     "lng": 68.97435600000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.24233837989272,
#                         "lng": 68.97580137989273
#                     },
#                     "southwest": {
#                         "lat": 22.23963872010728,
#                         "lng": 68.97310172010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "cd6f79b9f5af2b3224e5e8f0d1a72e8e831d5057",
#             "name": "The Dwarika Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 720,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114758383298146770726\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRZAAAA2qCFBLOtM7k6mrQyuCkhIXdc7DTmERYrbMPeJdlN2xx0OnSkGD4KAYzrnMwWztIjW83dW5xLVAphq3pWg__ckGjd41pmx2Of3SMjIQxzpQJ_2aiG5xWwpdsu4HAXhqQLEhDvmg0qAEHhdeQ4zQlwUXIBGhTjKygw0bVYU0B_8Yx9qg0uor0q5Q",
#                     "width": 1080
#                 }
#             ],
#             "place_id": "ChIJE4JnGSOcVjkRy3nX4HyoXg8",
#             "plus_code": {
#                 "compound_code": "6XRF+9P Dwarka, Gujarat, India",
#                 "global_code": "7JJC6XRF+9P"
#             },
#             "rating": 4,
#             "reference": "ChIJE4JnGSOcVjkRy3nX4HyoXg8",
#             "scope": "GOOGLE",
#             "types": [
#                 "cafe",
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 1139,
#             "vicinity": "Jamnagar Road, near Kandasbapu Ashram, Dwarka"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.2403017,
#                     "lng": 68.9737755
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.24170167989272,
#                         "lng": 68.97511652989272
#                     },
#                     "southwest": {
#                         "lat": 22.23900202010728,
#                         "lng": 68.97241687010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "a9cb6a757cf961cb3deecaa0b724cd2d7656a280",
#             "name": "Hotel Devkinandan",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2324,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101098013426098160179\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAEPpp6nbTI5L1Bnqck1Hym8s9nURw_wtGvy4lWJwj67oN72zFaT-YD6ZGp9Rbziuc2Ri_Ld-xr_EKBWIF8S-da-FvjCHgXO-sLrI0lze-oYxb8bFU2EpU1wNGhtZ3YpSREhCHRg-MaJH-sYEY37pm3Z32GhQx0lOqmBh5L-mJSHo2Z6R08TdNXw",
#                     "width": 1500
#                 }
#             ],
#             "place_id": "ChIJFcUUtE2dVjkRKW7IPNfK68g",
#             "plus_code": {
#                 "compound_code": "6XRF+4G Dwarka, Gujarat, India",
#                 "global_code": "7JJC6XRF+4G"
#             },
#             "rating": 4.6,
#             "reference": "ChIJFcUUtE2dVjkRKW7IPNfK68g",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 184,
#             "vicinity": "Near Kandas Bapu Ashram, Dwarkadhish Temple Main Road, Dwarka"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.2446336,
#                     "lng": 68.9654242
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.24579227989272,
#                         "lng": 68.96653727989272
#                     },
#                     "southwest": {
#                         "lat": 22.24309262010728,
#                         "lng": 68.96383762010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "4457e3b8f76d16ad022626c2b4019d4e734bd2c3",
#             "name": "Hotel Roma Kristo",
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112679937033506085491\">Deb M</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAhh_P4uw9ETgHJlUtNX1IejOFURU6IO4YGEbOSiY3llpULJKLFEa4hJUvHcU5RSyXn9oXANtZ_RRSQ5WduDdJNdxhvvLS3LgpWE9B3fmtjLfZ37VnPnBvf8m0IZxGjVWvEhAvtyHiBvg7qiiWQl0FAbUQGhTIAhws7SadA7ErlE16VJYfJO2ojQ",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJg04zpCicVjkRHDn0LMN9b7U",
#             "plus_code": {
#                 "compound_code": "6XV8+V5 Dwarka, Gujarat, India",
#                 "global_code": "7JJC6XV8+V5"
#             },
#             "rating": 4.4,
#             "reference": "ChIJg04zpCicVjkRHDn0LMN9b7U",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 854,
#             "vicinity": "Survey No. 3534 / 2A, Opp Rabari Gate"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.2418297,
#                     "lng": 68.961124
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.24324112989272,
#                         "lng": 68.96245217989272
#                     },
#                     "southwest": {
#                         "lat": 22.24054147010728,
#                         "lng": 68.95975252010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "ed765fdd4b3d090d5dda33478c2549222a40023a",
#             "name": "Hotel Devang",
#             "photos": [
#                 {
#                     "height": 3000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104228426987969781750\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA4j79vuwthEOK8p3Jz0zFgLfmOBkBBjTQFG9Lbsa9T5mTONFp7qykUJHXeuVQoI6AOdpJTwhLTMsLegc_W9lLdvif0hMiDVqnG9U9oJI9wKRfoKotGGcBh-qI8lKrUxGbEhDrFEH9YNxdhPG-tGTaVIxvGhQEn_9hfsI8CsVVN_SY6AnWSAoO8A",
#                     "width": 4496
#                 }
#             ],
#             "place_id": "ChIJGUJovi6cVjkR5YoFuO7oU5E",
#             "plus_code": {
#                 "compound_code": "6XR6+PC Dwarka, Gujarat, India",
#                 "global_code": "7JJC6XR6+PC"
#             },
#             "rating": 4.1,
#             "reference": "ChIJGUJovi6cVjkR5YoFuO7oU5E",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 317,
#             "vicinity": "Opp Circuit House, Hospital Rd, Dwarka"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.243404,
#                     "lng": 68.9698334
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.24480802989272,
#                         "lng": 68.97121977989272
#                     },
#                     "southwest": {
#                         "lat": 22.24210837010728,
#                         "lng": 68.96852012010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "3fef183ebaad0a28c41dac1900d8e2dd356b1f29",
#             "name": "HOTEL MEERA DWARKA",
#             "photos": [
#                 {
#                     "height": 5344,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103041022918860657055\">Ramanuj Singh</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAikuqb_cyM2iMiX90cSXk6-XFi4nLB2A-Bh5-ceLnTHxdq2H05IYr5sdeuEun9Q63vb9kbPzoM2iHjnkSqKBzAcB28gVHI7B0g7jftIfapKCYheg7-g0fGyKHnnsriP2sEhAEILFDwqxSqF8lAMDH2v6-GhT-rKUp9WCpBN0zr9Y1WZYG5j-S1Q",
#                     "width": 3006
#                 }
#             ],
#             "place_id": "ChIJ8XB2OyScVjkRKQagLIda3yw",
#             "plus_code": {
#                 "compound_code": "6XV9+9W Dwarka, Gujarat, India",
#                 "global_code": "7JJC6XV9+9W"
#             },
#             "rating": 3.6,
#             "reference": "ChIJ8XB2OyScVjkRKQagLIda3yw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 414,
#             "vicinity": "Dwarka"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.2439651,
#                     "lng": 68.9650065
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.24532137989272,
#                         "lng": 68.96636907989271
#                     },
#                     "southwest": {
#                         "lat": 22.24262172010728,
#                         "lng": 68.96366942010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "29e6cec5ef35c4bd152eef260a97f889b413192d",
#             "name": "Hotel Swati",
#             "photos": [
#                 {
#                     "height": 1280,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114408995951295254616\">Sharad Vithlani</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA8RshR35RQolpytWj0CE5HnaigphPCNx9dSFWULbUJBc5swF4w7AvyvnaBp4xEgA1xnsrVeE5s8Ae0oiddUXh26O7eKqv2DGlMKNhMVrSS9hoSLfV-f-M_big_y4bgotaEhBuhSogjx0hI0xbXLr235JhGhRicEw4tMjVXhf6HoUEdvOmqFzerQ",
#                     "width": 720
#                 }
#             ],
#             "place_id": "ChIJXUAfndKdVjkR8ZTkkFPP3cs",
#             "plus_code": {
#                 "compound_code": "6XV8+H2 Dwarka, Gujarat, India",
#                 "global_code": "7JJC6XV8+H2"
#             },
#             "rating": 4.4,
#             "reference": "ChIJXUAfndKdVjkR8ZTkkFPP3cs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 268,
#             "vicinity": "Bhadrakali Rd, opp. ICICI Bank, near Rabari Gate, Dwarka"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.244,
#                     "lng": 68.968
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.24513882989272,
#                         "lng": 68.96927897989272
#                     },
#                     "southwest": {
#                         "lat": 22.24243917010728,
#                         "lng": 68.96657932010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "e5f94d3265afb337d1ea73f6a6b0bc2c25e27641",
#             "name": "Blue Rock Hotel",
#             "place_id": "ChIJfwhu2CWcVjkRYFFqjesEKXE",
#             "plus_code": {
#                 "compound_code": "6XV9+H6 Dwarka, Gujarat, India",
#                 "global_code": "7JJC6XV9+H6"
#             },
#             "rating": 0,
#             "reference": "ChIJfwhu2CWcVjkRYFFqjesEKXE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "Dwarka Highway, opp. HP petrol Pump, Dwarka"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.1920064,
#                     "lng": 69.0201738
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.19356902989272,
#                         "lng": 69.02183422989272
#                     },
#                     "southwest": {
#                         "lat": 22.19086937010728,
#                         "lng": 69.01913457010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "dca6001aee6eba2f80555cf098b49f85fc1866b5",
#             "name": "Goverdhan Green Resort",
#             "photos": [
#                 {
#                     "height": 2000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105709617103697941613\">Goverdhan Greens</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAnUiA5IuLCxcZKq1957fHsK5wppAaUFqIoBT230cnxeP0FnPVpGRDsB8yq6VnX7-nGv64LhIiek5nwVYF6iJWkCT8haQv6rzqP6Him2HxpgdKFM_hwBevRQt2G8gsOvz3EhDOprJlGad7T2hxTq4fZDIXGhQXd8uPJGRIRNporIflzCfpvlkVfg",
#                     "width": 3000
#                 }
#             ],
#             "place_id": "ChIJk0WK0WubVjkRWC7Z1aTl8wM",
#             "plus_code": {
#                 "compound_code": "52RC+R3 Dwarka, Gujarat, India",
#                 "global_code": "7JJF52RC+R3"
#             },
#             "rating": 4,
#             "reference": "ChIJk0WK0WubVjkRWC7Z1aTl8wM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 540,
#             "vicinity": "National Highway 8 E, Baradiya Village, Devbhoomi, Dist. Jamnagar, Dwarka"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.2087586,
#                     "lng": 69.0131759
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.21011342989273,
#                         "lng": 69.01415002989272
#                     },
#                     "southwest": {
#                         "lat": 22.20741377010728,
#                         "lng": 69.01145037010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "8538d43c0a245a40e9c330320df076717d7d356d",
#             "name": "Cygnett Inn Dwarka",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112241949367596537091\">arti verma</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA3FUeuRgmzKYzxaVQacoNGjc0HY8w5La37iujciMIpEGG-y-9ln2_-4S9cgoXgwfJMw0OIvtOhxK49d2TKkp4n_G1tys7xxO6eLEaOU_qC62Dkp48yB_Jr1C0lkOaTC2OEhA910FRqlqUqFFQV0unh9gcGhToJ2fzLTBIWxBAYV97LRbdSQF6Og",
#                     "width": 4000
#                 }
#             ],
#             "place_id": "ChIJ08_hI3ibVjkRElNe7SUjssE",
#             "plus_code": {
#                 "compound_code": "6257+G7 Dwarka, Gujarat, India",
#                 "global_code": "7JJF6257+G7"
#             },
#             "rating": 4.3,
#             "reference": "ChIJ08_hI3ibVjkRElNe7SUjssE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 407,
#             "vicinity": "Survey No-356/1 To 6, Near Saibaba Mandir, Dwarka"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.239728,
#                     "lng": 68.964524
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.24107327989272,
#                         "lng": 68.96585577989272
#                     },
#                     "southwest": {
#                         "lat": 22.23837362010728,
#                         "lng": 68.96315612010729
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "ead870e7b6ee37c06b45dc9aed43c552c7509b20",
#             "name": "Hotel Narayan Inn",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 427,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111093478759960633088\">Hotel Narayan Inn</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAIrZ-YBRIdt7fnJdHeKWLlJtpeSmCyHYdGCo6J_hmnLeUmv8qognfJpHO5IS9R0xGHmhrYTOB7NsVqc2Cw-E7B6vpssBFGy4wNvRsNbvFq7TMzzOTshA0YEt8bXbq-A1xEhAlQiAVE-HBa9sbLjfAezshGhSyI3XbLHx8eSpna_h3W5DYGI0agA",
#                     "width": 640
#                 }
#             ],
#             "place_id": "ChIJe8Fvli-cVjkRPHrPZ_7-Ou8",
#             "plus_code": {
#                 "compound_code": "6XQ7+VR Dwarka, Gujarat, India",
#                 "global_code": "7JJC6XQ7+VR"
#             },
#             "rating": 3.9,
#             "reference": "ChIJe8Fvli-cVjkRPHrPZ_7-Ou8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 352,
#             "vicinity": "Opp Home Guard Office Home Guard Chowk, Dwarka"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.2462605,
#                     "lng": 68.9713385
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.24765022989272,
#                         "lng": 68.97263437989272
#                     },
#                     "southwest": {
#                         "lat": 22.24495057010727,
#                         "lng": 68.96993472010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "7377dd9e1dc60f64864a40ee2308727275acaa45",
#             "name": "The Grand Radhey",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 331,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104394101424774432465\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAerrZHLeFZTDrCi_PfrRouLdYicRusLNO1MwOiuZhOt7jARpFx7cVnqWx8xjugtFhInXF-HHe_BditPj4v2j2Z23EEuV4L6n7pRkw4FhwSspuPvYC89iUvKAhmVD8PTxKEhD2XSBTlFLzMdZzunNM9BapGhS8qHd-8bKkMBpVszXkXUdJyzKhNA",
#                     "width": 552
#                 }
#             ],
#             "place_id": "ChIJLaMs2iCcVjkRltjx8huFK2E",
#             "plus_code": {
#                 "compound_code": "6XWC+GG Ghanshyam Nagar, Dwarka, Gujarat, India",
#                 "global_code": "7JJC6XWC+GG"
#             },
#             "rating": 4,
#             "reference": "ChIJLaMs2iCcVjkRltjx8huFK2E",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 164,
#             "vicinity": "Ghanshyam Nagar, Dwarka"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.2381519,
#                     "lng": 68.9688669
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.23939607989272,
#                         "lng": 68.97026992989272
#                     },
#                     "southwest": {
#                         "lat": 22.23669642010728,
#                         "lng": 68.96757027010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "0acf711a9b719ba558d5e332f278c15edaaf75b3",
#             "name": "Hotel Gomti",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 728,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107648391518041602495\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAISuZ4qaEX8YtBp86CqyKZn43m03edTOwNfEEAWSJCWnjCnFvmozMcAUK4D1rUNO-gtqh3G9snnN0pOOQDTDqKKuNNsJzIbKvp3AmpI6tT4C8aijmBuYaqcJCo0FZ5_7FEhCH-M533ZvlUA53eXEkcQwrGhRMefqH0KekCggD3Ge0fyUA_JahQA",
#                     "width": 1080
#                 }
#             ],
#             "place_id": "ChIJWZjX1TqcVjkRyWI38SEn320",
#             "plus_code": {
#                 "compound_code": "6XQ9+7G Dwarka, Gujarat, India",
#                 "global_code": "7JJC6XQ9+7G"
#             },
#             "rating": 4.1,
#             "reference": "ChIJWZjX1TqcVjkRyWI38SEn320",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 448,
#             "vicinity": "Dhirubhai Ambani Marg, Opp. Gomti River, Dwarka"
#         }
#     ],
#     "status": "OK"
# }
# {
#     "html_attributions": [],
#     "next_page_token": "CrQCIgEAAFL20fWzY-ZCu9VoT-rfxDs9H-d-cUO1T29HT3rBUlTaF8IugCx673Dwi3ZmW0OU67dfFW7AtP7wza7fdknnfqRfr8TEr6AbmkFMHFT3taQNLPMWMP7vh-NC4gQgAh-k5_w2pE2_wB8ej3Yp9lapV88YJHrpaln7e7lN42z39OqBzzAw2JIjBQSE_-MEp88rd6VyRWh6jP5ioa2f4H-JnwEZk903kzfZs20iwezTMJFSiZYV3va2sF0b0n7TLwVVLxc_VqztZ4IkxhYsiczZFXws9sxnQSw8dmK1iT1d6FZ9P9EscuBYF0TuaTFp1bIoqbOZJec_lNScg-Cn91IO4Eb_mRPobHbde3GIXLpgbYgSAZ-BSb8NfjNUummc92eRm--9rnhWmAjU2kaTLt_UchcSEJyXY4e9b4MjBkUpMsb8DvAaFGcMscP72jlUqe7pAm-9ht02wBdm",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -8.5891214,
#                     "lng": 125.3411388
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -8.587656470107277,
#                         "lng": 125.3424764798927
#                     },
#                     "southwest": {
#                         "lat": -8.59035612989272,
#                         "lng": 125.3397768201072
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "72df5abfe575c246f69a881b2968532f370db5a6",
#             "name": "Caimeo Beach Resort",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3648,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116466541977909837702\">Caimeo Beach Camping</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAb8B0sSzoXo_QKNnIuYJ86HrKUEmwlus1wknSMsB_vjyFJifh54LehHFcCAMn7cGp30bCut4C40-7r1zIzM1RZAR6e9Nztmy3VfoxfSvDkrhTmVBi5xbJ_43l3B36diWUEhAutMSF7RYuriGrmnEye5h7GhQm_j5PmbLjjjn08MDrtUHB48eYyA",
#                     "width": 5472
#                 }
#             ],
#             "place_id": "ChIJFfz1PArRAS0RGmMz8PuHb68",
#             "plus_code": {
#                 "compound_code": "C86R+9F Liquica, Timor-Leste",
#                 "global_code": "6Q37C86R+9F"
#             },
#             "rating": 4.6,
#             "reference": "ChIJFfz1PArRAS0RGmMz8PuHb68",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 30,
#             "vicinity": "Rua Kamale Mutu, Liquica"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -8.548859499999999,
#                     "lng": 125.5867177
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -8.547414270107279,
#                         "lng": 125.5880417298927
#                     },
#                     "southwest": {
#                         "lat": -8.550113929892722,
#                         "lng": 125.5853420701073
#                     }
#                 }
#             },
# ...
#                         "lat": 22.78806482989272,
#                         "lng": 86.16498312989273
#                     },
#                     "southwest": {
#                         "lat": 22.78536517010728,
#                         "lng": 86.16228347010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "95e12cd2a620fad0fe7c9611fbbae516a967b1ad",
#             "name": "The Onyx Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2107,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110199460874268666697\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRZAAAALzEQlrrVkNjdqM-3awpe3_rrfI874arypJUccvitsTb2fdUDSIuzKktqWJ-bmV2Bcq4cWXc4ZgjlOv1nabC_YpWCAP9Tq-VmCrV9zN7V46wctO6JJ5zv_HPaTFVTD35EEhCSVHeTeANA1nDiXSL31KMLGhRnOO5bAfn1hVnJrW-5ysOERYfgow",
#                     "width": 3586
#                 }
#             ],
#             "place_id": "ChIJT9VfFL3k9TkRw4rZ0HzfFZY",
#             "plus_code": {
#                 "compound_code": "Q5P7+PF Adityapur, Jamshedpur, Jharkhand, India",
#                 "global_code": "7MJ8Q5P7+PF"
#             },
#             "rating": 4.2,
#             "reference": "ChIJT9VfFL3k9TkRw4rZ0HzfFZY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 364,
#             "vicinity": "Chowk, Tata Kandra Rd, beside V-Mart, Dindli Basti, Adityapur, Jamshedpur"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.5246883,
#                     "lng": 85.80858359999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.52584172989272,
#                         "lng": 85.81003732989271
#                     },
#                     "southwest": {
#                         "lat": 22.52314207010728,
#                         "lng": 85.80733767010726
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "b4cdcd947878e2e1b8eeaab035277a7ed8aa67bc",
#             "name": "Hotel Saffron Suites",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 512,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107007391273060649653\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAvGQa8iusV_zjYmoXryKQmO3nSdUSq3y94jfKxCIIYH0ezm03d9DRDahjm-b54rtY3S9m5XJzGxFNaf2k5mvfLfX_lZm6N04AsROYYGVvEpC_xwoQ32nEW-Y2qJkzWaetEhDDpyvlTtSpwAZatcOQLLaJGhRD212LLz7l5hiaTWht_q5EO_cNLQ",
#                     "width": 1040
#                 }
#             ],
#             "place_id": "ChIJfS3cRQcnHjoRWUGVIjtinGo",
#             "plus_code": {
#                 "compound_code": "GRF5+VC Chaibasa, Jharkhand, India",
#                 "global_code": "7MJ7GRF5+VC"
#             },
#             "rating": 4.2,
#             "reference": "ChIJfS3cRQcnHjoRWUGVIjtinGo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 659,
#             "vicinity": "College More, Matkamhatu, Chaibasa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.6750933,
#                     "lng": 86.2480563
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.67662572989272,
#                         "lng": 86.24920197989273
#                     },
#                     "southwest": {
#                         "lat": 22.67392607010727,
#                         "lng": 86.24650232010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "3e5af52507a42ce5b3b6fa6ad5a23f2848bdda81",
#             "name": "The Weekend Resort",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101215480379091616495\">Subhasish Dutta</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA4aHlVq6e8t_SbVMoxmIUYz3qwSKA2-ZMqi9m-hPrvhsqDsGvtFy81tjOY2R4IopSmE8PjpZvQdY_LDUPmc_GUsullhX7pVk0H9I0N6mSnvmU9Kgqy7OrvYYvTGhGwC23EhCvBnHXFhZ4Orz9MCelOMP1GhQCvqpNCK3qDAabGMAGfzU6X3Klyw",
#                     "width": 4000
#                 }
#             ],
#             "place_id": "ChIJQ8C3OPT89TkRnDJqK83Knw4",
#             "plus_code": {
#                 "compound_code": "M6GX+26 Sunder Nagar, Jamshedpur, Jharkhand, India",
#                 "global_code": "7MJ8M6GX+26"
#             },
#             "rating": 4,
#             "reference": "ChIJQ8C3OPT89TkRnDJqK83Knw4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 196,
#             "vicinity": "Jamshedpur - Chaibasa Rd, Turamdih, Sunder Nagar, Jamshedpur"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.8410058,
#                     "lng": 86.20231919999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.84235967989272,
#                         "lng": 86.20373597989271
#                     },
#                     "southwest": {
#                         "lat": 22.83966002010727,
#                         "lng": 86.20103632010726
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "3bcb67512fd812681dc763f4b68962bc5a305764",
#             "name": "The Mahal Inn",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108524047708448519945\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRZAAAAI23XV10Anpvcph9NcmfRQi8yxf2-f1mPcG5-fUvBdTukeHvynk4M5O4S6aWRvL9LHCLmVOEZOrNt_lvzJ5SeIYraI_TBs-dSxP_5CC7VbFt4yEWk4Etb_6IshQ-TgW0pEhBxIOd2V_usxDXk1AvOztZWGhTGurdEMylTZKslxq5onP41nPR90w",
#                     "width": 3696
#                 }
#             ],
#             "place_id": "ChIJ5Zro7sbj9TkRsOGm0hNR21k",
#             "plus_code": {
#                 "compound_code": "R6R2+CW Mango, Jamshedpur, Jharkhand, India",
#                 "global_code": "7MJ8R6R2+CW"
#             },
#             "rating": 4.2,
#             "reference": "ChIJ5Zro7sbj9TkRsOGm0hNR21k",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 752,
#             "vicinity": "Pardih Rd, Chepapul, Mango, Jamshedpur"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.8025656,
#                     "lng": 86.2044069
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.80390812989272,
#                         "lng": 86.20574437989272
#                     },
#                     "southwest": {
#                         "lat": 22.80120847010728,
#                         "lng": 86.20304472010729
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "e86ffd265ddc5287c69842c00b001744dd3f3690",
#             "name": "Hotel Hill View",
#             "photos": [
#                 {
#                     "height": 1128,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118124499726588020423\">shiva Mahato</a>"
#                     ],
#                     "photo_reference": "CmRaAAAALfbI1TKsxtksTr8f8Q9VZMv1c-pehvJrBtsD_AJRgCq-55cJC5fWYyU8OvSjmpmvbbN9Umu7yRD8M-DM5PBFRT0KcDIycyzRbEIEnVVqAbANPPPOxHYTm3ZIFg3_z315EhBpY3LgdshgCxdE8a9gc70OGhR0dqB-GeKy-ZIRSVaAE7LQ0ZixJw",
#                     "width": 2004
#                 }
#             ],
#             "place_id": "ChIJr5Bz6g_j9TkRvcYhxYz8-6M",
#             "rating": 3.5,
#             "reference": "ChIJr5Bz6g_j9TkRvcYhxYz8-6M",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 47,
#             "vicinity": "L1-6, New Kalimati Rd, Sakchi, Jamshedpur"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.788908,
#                     "lng": 86.18392109999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.79025432989273,
#                         "lng": 86.18535562989271
#                     },
#                     "southwest": {
#                         "lat": 22.78755467010728,
#                         "lng": 86.18265597010726
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "1d51272c57b3e0c50051e10c580e1af9e53468da",
#             "name": "Darshan Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4608,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110301148969198151645\">Nalinikanta Mohanty</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAfjwNVH0UNqC7iQnbW2kCMIA8LHQUs_gPHqlfEpege9_OWTmQtTzFiO8nAuBD2QCUAHu5GMYdOT51Uov2U769fUPc2umVcRqD0882HpNffgskPuWuDIzjAhxLGTbS07IiEhBZ_KU29-m2mML1OqLN-fT_GhSCh0pfze5__XXegPmKlnnuAN__TQ",
#                     "width": 3456
#                 }
#             ],
#             "place_id": "ChIJhTBoYF3j9TkR6ARFZgd72jk",
#             "plus_code": {
#                 "compound_code": "Q5QM+HH Jamshedpur, Jharkhand, India",
#                 "global_code": "7MJ8Q5QM+HH"
#             },
#             "rating": 3.9,
#             "reference": "ChIJhTBoYF3j9TkR6ARFZgd72jk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 470,
#             "vicinity": "2, Opposite Ram Mandir, Main Road, Bistupur, Jamshedpur"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 22.809387,
#                     "lng": 86.2029214
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 22.81073792989272,
#                         "lng": 86.20428052989271
#                     },
#                     "southwest": {
#                         "lat": 22.80803827010728,
#                         "lng": 86.20158087010726
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "1e0fe7cf7de717ba276ffaabd8aaa3c4208e4bf3",
#             "name": "Hotel Sai Regency",
#             "photos": [
#                 {
#                     "height": 958,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103058757728485289759\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAXyRD-1F9I2LKljDWs_t1GiET-JfuJWdDIjEgBp11_kWet1K8LUKWkUhK61ybhDB8_LVqN-PcKwtro9bdeMobSNBYzncpM6cAOmSB89xaNHwWMDrcfRqg0vDajMiLvzNDEhBiVPVzwL8tAdW8sB_HvhI4GhRv4HoRctKqoFTGtDPfSa2Siqkjug",
#                     "width": 576
#                 }
#             ],
#             "place_id": "ChIJOe2GFl3j9TkRsGlxyQITsuI",
#             "plus_code": {
#                 "compound_code": "R653+Q5 Sakchi, Jamshedpur, Jharkhand, India",
#                 "global_code": "7MJ8R653+Q5"
#             },
#             "rating": 4.1,
#             "reference": "ChIJOe2GFl3j9TkRsGlxyQITsuI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 55,
#             "vicinity": "140 New, SNP Area, Ambagan, Sakchi, Jamshedpur"
#         }
#     ],
#     "status": "OK"
# }
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0        Koungheul           0      SN  1584487523        33  13.98  -14.80
# 1           Dwārka           0      IN  1584487619        65  22.24   68.97
# 2            Airai           0      TL  1584487591        67  -8.93  125.41
# 3             Buin           0      CL  1584487736        40 -33.73  -70.75
# 4   Port Elizabeth           0      ZA  1584487747        64 -33.92   25.57
# 5            Bilma           0      NE  1584487758         9  18.69   12.92
# 6             Sami           0      GM  1584487760        30  13.58  -15.20
# 7        Swan Hill           0      AU  1584487861        40 -35.34  143.55
# 8         Flinders           0      AU  1584487703        64 -34.58  150.86
# 9    Graaff-Reinet           0      ZA  1584487934        62 -32.25   24.53
# 10          Kadhan           0      PK  1584487992        27  24.48   68.99
# 11           Dubai           0      AE  1584487923        57  25.26   55.30
# 12   Moreira Sales           0      BR  1584487896        84 -24.06  -53.01
# 13           Nioro           0      GM  1584488050        43  13.35  -15.75
# 14     Santa Maria           0      BR  1584488053        66 -29.68  -53.81
# 15     Broken Hill           0      AU  1584488093        40 -31.95  141.43
# 16       Moss Vale           0      AU  1584488099        64 -34.55  150.38
# 17        Jugsālai           0      IN  1584488101        44  22.77   86.18
#
#     Max Temp  Wind Speed                           Hotel Name
# 0     76.046        5.35                        Hotel Cabourg
# 1     77.990        4.16                VITS Devbhumi, Dwarka
# 2     73.166        2.02                  Caimeo Beach Resort
# 3     75.470        3.10           The Ritz-Carlton, Santiago
# 4     70.070        3.60   Radisson Blu Hotel, Port Elizabeth
# 5     73.670        4.25
# 6     77.360        4.84                       Lodge Kabacoto
# 7     79.268        2.24                  Murray Downs Resort
# 8     74.264        3.60                  Peppers Manor House
# 9     71.276        0.89  Mount Camdeboo Private Game Reserve
# 10    70.358        2.45                Creek Way Hotel Badin
# 11    78.278        1.50      JW Marriott Marquis Hotel Dubai
# 12    75.020        2.34                 ibis Styles Umuarama
# 13    74.462        4.92                        Hôtel Sindola
# 14    75.704        3.25                       Itaimbé Palace
# 15    73.670        4.60                 Royal Exchange Hotel
# 16    75.272        3.60                  Peppers Manor House
# 17    70.340        0.91                    Ramada Jamshedpur

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations,
    info_box_content=[f"Hotel loc: {rate}" for rate in hotel_info])

fig.add_layer(markers)

# Display Map
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
